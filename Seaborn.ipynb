# %%
#objective
#tools and modules
#data description 
#data preprocessing
#EDA outlier analysis, missing values, 
#feature engineering
#Analysis prediction
#conclusion
#references

# %% [markdown]
# #introduction to visualisation
#
# 1. easy for understanding compare to text data
# 2. EDA exploratory data Analysis
#
# visualising our data for better understanding
# corelated with each other, how its affecting output or target
# Feature engineering base : creation of new feauture from already available one
#
# ref: https://towardsdatascience.com/exploratory-data-analysis-in-python-c9a77dfa39ce
#
# Univariate analysis Only one feature for understanding
# Bivariate Analysis Two variables/features
# Multivarate Analysis more than two

# %%
#Statistical data visualisation Using seaborn
#https://seaborn.pydata.org/api.html#relational-api

#univariate/bi-variate/multi-variate

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set()

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Relational plots
#
# https://seaborn.pydata.org/generated/seaborn.relplot.html

# %%
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="smoker")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day")

# %%
sns.relplot(x = "total_bill", y = "tip", data= tips, style="smoker")

# %%
sns.relplot(x = "total_bill", y = "tip", data= tips, style = "day", hue = "smoker")

# %%
sns.relplot(x ="total_bill", y="tip", data=tips, hue="size")

# %%
sns.relplot(x = "total_bill", y="tip", data = tips, col="day")

# %%
sns.relplot(x = "total_bill", y="tip", data = tips, col="day", col_wrap=2 )

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "size", data = tips, palette = 'ch:r=0.8, l=0.95')

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "size", data = tips, palette = 'ch:r=0.25, l=0.5')

# %% [markdown]
# palette: https://seaborn.pydata.org/tutorial/color_palettes.html?highlight=palette

# %%
sns.relplot(x ="total_bill", y="tip", data=tips, size="size", sizes=(1,100))

# %%
sns.relplot(x = "total_bill", y="tip", data=tips, kind = "line")

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line")

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", ci=False)

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", ci="sd")

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", estimator=None)

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", estimator=None, hue = "event")

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", hue = "event")

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", hue = "event", style="event")

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", hue = "region", style="event")

# %%
sns.relplot(x = "timepoint", y = "signal", data = fmri, kind="line", hue = "event", style="event", markers = True)

# %%
dots = sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
dots["align"].value_counts()
# Out:
# sacc    454
# dots    394
# Name: align, dtype: int64

# %%
dots = sns.load_dataset("dots").query("align == 'sacc'")
dots.head()
# Out:
#     align choice  time  coherence  firing_rate
# 394  sacc     T1  -600        0.0    45.232512
# 395  sacc     T1  -580        0.0    45.426403
# 396  sacc     T1  -560        0.0    43.071647
# 397  sacc     T1  -560        3.2    44.633471
# 398  sacc     T1  -540        0.0    45.479431

# %%
dots = sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x = "time", y = "firing_rate", data = dots, kind="line")

# %%
sns.relplot(x = "time", y = "firing_rate", data = dots, kind="line", hue="align")

# %%
sns.relplot(x = "time", y = "firing_rate", data = dots, kind="line", hue="coherence")

# %%
sns.relplot(x = "time", y = "firing_rate", data = dots, kind="line", hue="coherence", style="choice")

# %%
palette = sns.cubehelix_palette(light = 0.5, n_colors=6)
sns.relplot(x = "time", y = "firing_rate", data= dots)
sns.relplot(x = "time", y = "firing_rate", data= dots,kind = "line")
sns.relplot(x = "time", y = "firing_rate", data= dots,kind = "line", hue="coherence")
sns.relplot(x = "time", y = "firing_rate", data= dots,kind = "line", hue="coherence", style="choice")
sns.relplot(x = "time", y = "firing_rate", data= dots,kind = "line", hue="coherence", style="choice",palette=palette)

# %%
tips = sns.load_dataset("tips")

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", data = tips, col="size")

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", data = tips, col="size", col_wrap=2)

# %% [markdown]
# ### Line plot
#
# Reference: https://seaborn.pydata.org/generated/seaborn.lineplot.html#seaborn.lineplot

# %%
sns.lineplot(x= "total_bill", y = "tip", data= tips)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = "timepoint", y = "signal", data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "event", data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event", data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event",markers=True, data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event",markers=True, ci = None, data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event",markers=True, ci = 50, data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event",markers=True, ci = 50, data = fmri, err_style="bars")

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "event", data = fmri.query("region == 'frontal'"))

# %% [markdown]
# ### Scatterplot
# Ref: https://seaborn.pydata.org/generated/seaborn.scatterplot.html#seaborn.scatterplot

# %%
sns.scatterplot(x= "total_bill", y = "tip", data= tips)

# %%
sns.scatterplot(x= "total_bill", y = "tip", hue = "size", data= tips)

# %%
sns.scatterplot(x= "total_bill", y = "tip", hue = "smoker", data= tips)

# %%
sns.scatterplot(x= "total_bill", y = "tip", hue = "smoker",size="size", data= tips)

# %%
sns.scatterplot(x= "total_bill", y = "tip", hue = "smoker",size="size", style="time", data= tips)

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x= "sepal_length", y ="petal_length", data=iris)

# %%
sns.scatterplot(x = iris["sepal_length"], y = iris["petal_length"])

# %% [markdown]
# ### Catplot

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x = "day", y = "total_bill", data=tips)

# %%
sns.catplot(y = "day", x = "total_bill", data=tips)

# %%
sns.catplot(x = "day", y = "total_bill", data=tips, jitter=False)

# %%
sns.catplot(x = "day", y = "total_bill", data=tips, kind= "swarm")

# %%
sns.catplot(x = "day", y = "total_bill", data=tips, kind= "swarm", hue="sex")

# %%
sns.catplot(x = "day", y = "total_bill", data=tips, kind= "swarm", hue="size")

# %%
sns.catplot(x = "smoker", y = "total_bill", data = tips)

# %%
sns.catplot(x = "smoker", y = "total_bill", data = tips, order=["No","Yes"])

# %%
sns.catplot(x = "smoker", y = "total_bill", kind = "box", data = tips)

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", data = tips)

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", data = tips, hue="sex")

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", data = tips, hue="time")

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", data = tips, hue="smoker")

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", data = tips, hue="smoker", dodge=False)

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = "color", y ="price", kind = "boxen", data = diamonds)

# %%
sns.catplot(x = "color", y ="price", kind = "boxen", data = diamonds.sort_values("color"))

# %%
sns.catplot(x = "day", y ="total_bill", kind = "boxen", data = tips, hue = "sex")

# %%
sns.catplot(x = "day", y ="total_bill", kind = "boxen", data = tips, hue = "sex", dodge=False)

# %%
sns.catplot(x = "day", y ="total_bill", kind = "violin", data = tips)

# %%
sns.catplot(x = "day", y ="total_bill", kind = "violin", data = tips, hue = "sex")

# %%
sns.catplot(y = "day", x ="total_bill", kind = "violin", data = tips, hue = "sex")

# %%
sns.catplot(y = "day", x ="total_bill", kind = "violin", data = tips, hue = "sex", split= True)

# %%
sns.catplot(y = "day", x ="total_bill", kind = "violin", data = tips, hue = "sex", split= True, inner="stick")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x = "sex", y = "survived", data= titanic, kind = "bar", hue="class")

# %%
sns.catplot(x = "deck", data= titanic, kind = "count", palette='ch:0.25')

# %%
sns.catplot(x = "class", data= titanic, kind = "count", palette='ch:0.25')

# %%
sns.catplot(x = "embarked", data= titanic, kind = "count", palette='ch:0.25')

# %%
sns.catplot(x = "embarked", data= titanic, kind = "count", palette='ch:0.25', hue ="sex")

# %%
sns.catplot(x = "sex", y="survived", data=titanic, kind="point",hue="class")

# %% [markdown]
# ### Boxplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(style="whitegrid")
sns.boxplot(y = tips["total_bill"])

# %%
sns.set(style="darkgrid")
sns.boxplot(x = tips["total_bill"])

# %%
sns.boxplot(x = "day", y = "total_bill", data=tips)

# %%
sns.boxplot(data=tips, x ="day", y="total_bill", hue="smoker")

# %%
sns.boxplot(data=tips, x ="day", y="total_bill", hue="smoker", palette="coolwarm")

# %% [markdown]
# ### Possible values for palette are:
# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r

# %%
sns.boxplot(data=tips, x ="day", y="total_bill", hue="smoker", palette="Accent_r", linewidth=4.5)

# %%
sns.boxplot(data=tips, x="time", y="total_bill", hue="smoker", order=["Dinner", "Lunch"])

# %%
sns.boxplot(data= tips, orient="h", palette="Set2")

# %%
#boxplot with swarmplot

sns.boxplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")

# %% [markdown]
# ### Boxen plot

# %%
sns.boxenplot(data =tips, x = "total_bill")

# %%
sns.boxenplot(data =tips, y = "total_bill")

# %%
sns.boxenplot(data =tips, y = "total_bill", x = "day")

# %%
sns.boxenplot(data =tips, y = "total_bill", x = "day", palette="Set2")

# %%
sns.boxenplot(data =tips, y = "total_bill", x = "day", palette="Set3",linewidth="5")

# %%
sns.boxenplot(data =tips, y = "total_bill", x = "day", palette="Set1",linewidth=10,hue="smoker")

# %% [markdown]
# ### Swarm plot

# %%
sns.swarmplot(data =tips, x = "total_bill")

# %%
sns.swarmplot(data =tips, y = "total_bill")

# %%
sns.swarmplot(data =tips, y = "total_bill", x = "day")

# %%
sns.swarmplot(data =tips, y = "total_bill", x = "day", palette="Set2")

# %%
sns.swarmplot(data =tips, y = "total_bill", x = "day", palette="Set3",hue="smoker")

# %%
sns.swarmplot(data =tips, y = "total_bill", x = "day", palette="Set1",hue="smoker", dodge=True)

# %%
sns.swarmplot(data =tips, y = "total_bill", x = "day", palette="Set1",hue="smoker", dodge=True, size =8)

# %%
sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
sns.swarmplot(x="tip", y="day", data=tips, color=".2")

# %%
sns.boxplot(x="tip", y="day", data=tips)
sns.swarmplot(x="tip", y="day", data=tips, color=".2")

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips,color="pink", edgecolor="gray")

# %%
#violin plot with swarm plot
sns.violinplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips,color="white", edgecolor="gray")

# %% [markdown]
# ###  Bar plot

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.barplot.html#seaborn.barplot

# %% [markdown]
# ###  Count plot

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot

# %% [markdown]
#  ### Violin plot

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.countplot.html#seaborn.countplot

# %% [markdown]
# ### stripplot

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.stripplot.html#seaborn.stripplot

# %% [markdown]
# ### Distplot

# %%
sns.distplot(tips["total_bill"])

# %%
sns.distplot(tips["total_bill"], hist=False)

# %%
sns.distplot(tips["total_bill"], hist=False, rug=True)

# %%
sns.distplot(tips["total_bill"], kde=False)

# %%
sns.distplot(tips["total_bill"], vertical=True)

# %%
sns.set_color_codes()
sns.distplot(tips["tip"], color="m")

# %%
sns.distplot(tips["total_bill"], color="y", norm_hist=True)

# %%
from scipy.stats import norm
sns.distplot(tips["total_bill"], color="y", fit=norm, kde =False)

# %% [markdown]
# x = 5 ,6 7, 8, 10
# x = 0.5, 0.6, 0.7, 0.8, 1
#
# y = 100, 110, 120, 200, 250
# y = 0.4, 0,42, 0,44, 0.8, 1.0
#
#  0 to 1
#
# standardisation -1 to +1
#
# converting date in to a specific range

# %% [markdown]
# ### kdeplot

# %%
sns.kdeplot(tips["total_bill"])

# %%
sns.kdeplot(tips["total_bill"], shade=True)

# %%
sns.kdeplot(tips["total_bill"], shade=True, color= "g")

# %%
sns.kdeplot(tips["total_bill"], tips["tip"])

# %%
sns.kdeplot(tips["total_bill"], tips["tip"], shade=True)

# %%
sns.kdeplot(tips["total_bill"], tips["tip"], color="y", shade=True)

# %% [markdown]
# ### Heatmap

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot("month", "year","passengers")
ax =sns.heatmap(flights)

# %%
sns.heatmap(flights, annot=True,fmt="d")

# %%
sns.heatmap(flights, annot=True,fmt="d",  cmap="YlGnBu")

# %%
sns.heatmap(flights, annot=True,fmt="d",  cmap="YlGnBu",cbar=False)

# %% [markdown]
# ### Other plots

# %%
sns.pairplot(data=tips)

# %%
sns.regplot(x = "total_bill", y ="tip", data=tips)

# %%
sns.lmplot(x = "total_bill", y ="tip", data=tips)

# %%
sns.regplot(x = "total_bill", y ="tip", data=tips, order=3)


#4x + 7
#x2 + x + 1
#x3 + x2 + x +8

# %%
sns.regplot(x = "total_bill", y ="tip", data=tips,  robust = True)

# %%
sns.lmplot(x = "total_bill", y ="tip", data=tips,  robust = True, hue= "sex")

# %%
#Complete info: https://seaborn.pydata.org/api.html#relational-api

# %%
import seaborn as sns
from matplotlib import pyplot as plt

fmri = sns.load_dataset("fmri")

sns.lineplot(x = "timepoint", y = "signal", data = fmri)

plt.savefig("img_1")
